# %%
import os
import fnmatch
import cv2
import numpy as np
import string
import time
 
from keras.preprocessing.sequence import pad_sequences
 
from keras.layers import Dense, LSTM, Reshape, BatchNormalization, Input, Conv2D, MaxPool2D, Lambda, Bidirectional
from keras.models import Model
from keras.activations import relu, sigmoid, softmax
import keras.backend as K
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
 
import tensorflow as tf

# %%
# !wget https://thor.robots.ox.ac.uk/~vgg/data/text/mjsynth.tar.gz

# %%
# !tar -xvzf mjsynth.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# mnt/ramdisk/max/90kDICT32px/2717/2/291_Dethrone_21191.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/290_cruelly_18370.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/289_works_87244.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/288_UPHOLSTERED_83520.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/287_plaited_58007.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/286_TOURISTY_79890.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/285_slavic_71550.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/284_labrador_43023.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/283_DETERMINEDLY_21171.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/282_femur_28535.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/281_HESITATE_35963.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/280_FANCYING_28069.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/279_Meadow_47378.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/278_Carters_11749.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/277_Geologically_32213.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/276_Scullions_68804.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/275_nosier_52332.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/274_organdy_53698.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/273_Confided_15911.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/272_Indissolubly_39071.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/271_DECAGON_19625.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/270_Refuse_63954.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/269_SEAWORTHIEST_68981.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/268_TERRACING_78281.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/267_springs_73784.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/266_PARDONABLY_55530.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/265_watchmaking_85616.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/264_SOWS_72995.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/263_Obsolete_52899.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/262_jabots_41086.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/261_Palmate_55163.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/260_PLAYGIRL_58148.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/259_housemates_37081.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/258_OBJECTIONS_52783.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/257_WATERLOGGED_85657.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/256_Undefinable_82053.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/255_prosier_60735.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/254_titivate_79338.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/253_Quell_61794.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/252_Broiled_9712.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/251_FRANCHISE_30625.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/250_Paintbrushes_55044.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/249_Sanitizes_67732.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/248_HALIFAX_34619.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/247_shocker_70337.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/246_curve_18787.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/245_BARONAGE_6026.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/244_perfunctory_56659.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/243_bonk_8675.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/242_kingfisher_42545.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/241_Vibrantly_84506.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/240_hearthrug_35473.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/239_Almighty_2183.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/238_serapes_69559.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/237_streamline_75133.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/236_Defenseless_20012.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/235_munching_50409.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/234_captions_11407.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/233_RUNGS_67095.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/232_Tomographic_79555.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/231_SIMS_71023.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/230_BUCKED_9944.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/229_Canvased_11282.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/228_DOIN_23128.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/227_oils_53226.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/226_Unbolting_81812.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/225_Ankle_2930.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/224_Poll_58624.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/223_SYNONYM_77034.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/222_skinniest_71333.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/221_SHYER_70677.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/220_Portables_58954.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/219_qm_61591.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/218_gregory_33671.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/217_Incivility_38752.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/216_CHANCE_12616.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/215_Vengeful_84255.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/214_Cozening_17698.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/213_Crock_18191.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/212_VOCATION_84955.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/211_Commends_15194.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/210_visited_84825.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/209_Tautest_77711.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/208_MODERATING_49272.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/207_nonobjective_52069.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/206_blackcurrants_7786.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/205_Gilds_32463.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/204_YIELDINGS_87790.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/203_croakiest_18175.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/202_Affirmatively_1420.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/201_Iyer_41063.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/200_Explicating_27444.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/199_veld_84204.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/198_interspersion_40383.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/197_ARTICULATION_4135.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/196_keelhauls_42223.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/195_PREDATORY_59513.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/194_Chivalrousness_13332.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/193_calibration_10872.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/192_misogamy_48987.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/191_prints_60139.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/190_plants_58053.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/189_Saltiness_67532.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/188_Verisimilitude_84358.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/187_parroting_55651.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/186_NINETIETH_51714.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/185_Robotic_66396.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/184_Usual_83749.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/183_spurious_73847.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/182_CLOTHESPINS_14328.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/181_stallone_74176.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/180_BEEKEEPING_6633.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/179_golfed_33065.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/178_SPROUTED_73814.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/177_Precancels_59429.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/176_Helm_35711.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/175_TEASERS_77840.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/174_Outdistances_53998.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/173_LIBRETTISTS_44325.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/172_paganini_54990.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/171_CINERAMA_13692.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/170_Pokey_58534.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/169_glycerin_32879.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/168_Twee_81347.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/167_neuter_51410.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/166_sons_72760.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/165_unluckily_82852.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/164_FLYBY_29854.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/163_caddishly_10710.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/162_sardinia_67796.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/161_Williwaw_86627.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/160_resistors_65192.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/159_eloquently_25150.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/158_acyclovir_921.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/157_brigitte_9578.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/156_Brazzaville_9325.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/155_Ceilidhs_12260.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/154_Neurotically_51405.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/153_palatalize_55079.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/152_BIRD_7623.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/151_know_42789.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/150_Unwiser_83441.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/149_Recursions_63447.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/148_SCHOLARS_68331.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/147_Bathers_6229.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/146_Nonentity_51992.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/145_dots_23400.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/144_Hydroponics_37562.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/143_trammeled_80107.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/142_Rooney_66620.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/141_Gravels_33540.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/140_outflanked_54036.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/139_Punting_61301.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/138_JEWELER_41481.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/137_RAGGED_62184.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/136_beefing_6623.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/135_echinoderm_24504.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/134_CARTESIAN_11750.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/133_padlocks_54979.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/132_URBANELY_83641.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/131_nickel_51574.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/130_cessna_12499.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/129_hallows_34641.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/128_ruffs_67007.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/127_CONNUBIAL_16183.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/126_psychoanalytically_61012.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/125_alisha_2034.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/124_REGRESSED_64048.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/123_windlasses_86706.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/122_logier_45098.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/121_Fernandez_28571.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/120_MULTIFARIOUS_50327.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/119_Physicist_57391.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/118_Peacetime_56116.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/117_OUZOS_54265.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/116_WAHOO_85226.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/115_IMPLORES_38372.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/114_Runaway_67088.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/113_AMBULATION_2420.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/112_halibut_34617.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/111_detainees_21136.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/110_enfranchises_25765.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/109_giannini_32381.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/108_MALENESS_46260.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/107_RWANDANS_67208.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/106_XXXI_87592.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/105_Replenishes_64828.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/104_Immutable_38161.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/103_Grassing_33498.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/102_Cinebar_13682.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/101_Stylists_75476.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/100_LEXIS_44252.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/99_Timberwolf_79125.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/98_dmd_22973.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/97_Ashikaga_4238.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/96_really_62807.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/95_STICKPIN_74670.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/94_Vegetarianism_84167.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/93_RETAILED_65442.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/92_Epigraph_26208.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/91_excretory_27126.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/90_Paddlers_54966.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/89_ABASHES_187.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/88_coccyges_14569.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/87_slr_71842.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/86_COLLECTED_14899.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/85_SIDELIGHT_70753.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/84_TRANQUILIZED_80140.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/83_spiderwebs_73386.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/82_TORQUEMADA_79749.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/81_CROMWELL_18208.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/80_clobbered_14251.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/79_unfastens_82448.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/78_Ogres_53195.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/77_ABJURES_288.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/76_flack_29262.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/75_SQUEEZER_73969.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/74_Inculcates_38904.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/73_malfunctioned_46270.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/72_faulkner_28288.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/71_JOCKS_41624.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/70_trammel_80106.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/69_WEENIER_85914.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/68_distinct_22757.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/67_INDICATION_39015.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/66_center_12369.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/65_weer_85934.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/64_FOOLSCAP_30040.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/63_habitat_34436.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/62_inlays_39632.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/61_PANICKED_55271.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/60_declaimer_19752.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/59_Usherette_83733.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/58_faddiness_27875.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/57_tartary_77603.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/56_PHEASANT_57152.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/55_GUARANTY_34061.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/54_pylori_61542.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/53_Exclamatory_27088.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/52_Consciences_16202.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/51_Innocuous_39663.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/50_EMBARRASSMENT_25247.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/49_INEXCUSABLE_39235.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/48_Fluorescing_29805.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/47_complexions_15476.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/46_RESPONSIBLE_65287.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/45_Daffiest_19021.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/44_cachepots_10686.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/43_brambliest_9214.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/42_titter_79355.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/41_graduation_33338.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/40_normative_52263.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/39_HOGAN_36422.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/38_fauvism_28314.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/37_DICKEY_21479.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/36_reheating_64133.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/35_Subfreezing_75553.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/34_SCIENCES_68406.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/33_liberates_44299.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/32_STONEWALLING_74890.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/31_mightiness_48345.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/30_Myelitis_50678.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/29_BASELY_6129.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/28_Antimalarial_3203.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/27_PROGRESSION_60444.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/26_adherence_1016.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/25_BRAHMANS_9166.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/24_capsules_11391.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/23_PH_57093.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/22_april_3656.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/21_uncurl_82032.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/20_BALLGIRLS_5642.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/19_handy_34842.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/18_Charily_12767.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/17_PIPIT_57784.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/16_DISTILLING_22755.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/15_Chickasaws_13134.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/14_Idealization_37793.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/13_monongahela_49605.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/12_CORREGGIO_17156.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/11_Entangling_25979.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/10_ARABESQUES_3711.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/9_dam_19098.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/8_Hoodlum_36733.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/7_backcombs_5325.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/6_Mischievousness_48828.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/5_sobbingly_72428.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/4_Palm_55162.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/3_Readjustment_62750.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/2_CRIMINAL_18085.jpg
# mnt/ramdisk/max/90kDICT32px/2717/2/1_Candidacies_11131.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/
# mnt/ramdisk/max/90kDICT32px/2717/1/501_RAISES_62261.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/500_vaporizer_84035.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/499_PARODISTS_55622.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/498_Pear_56141.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/497_annex_2954.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/496_duskiness_24211.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/495_CARPENTERING_11684.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/494_climate_14162.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/493_Enacting_25515.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/492_MEGASTAR_47586.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/491_sensitizes_69440.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/490_CAPABLY_11299.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/489_FEATHERING_28384.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/488_App_3445.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/487_BLARING_7906.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/486_Ujungpandang_81592.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/485_Blats_7939.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/484_Discomforting_22074.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/483_LINDSAY_44597.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/482_Vichyssoise_84543.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/481_DUMPINESS_24112.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/480_INSEMINATE_39773.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/479_PROPITIATORY_60643.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/478_precancels_59429.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/477_michelson_48174.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/476_wilson_86641.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/475_CALIBRATING_10871.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/474_POOR_58848.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/473_DWARFISH_24259.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/472_squatted_73927.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/471_WWW_87505.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/470_eaton_24461.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/469_band_5718.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/468_PPR_59305.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/467_OVERSPENT_54703.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/466_Quest_61816.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/465_legged_43945.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/464_Tar_77530.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/463_SCHEMATIC_68252.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/462_World_87260.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/461_Speedier_73279.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/460_Rustically_67159.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/459_UNPICKED_82962.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/458_taliban_77309.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/457_EPISCOPAL_26221.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/456_testing_78382.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/455_SLEDDING_71580.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/454_reconstructive_63321.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/453_GODLESSNESS_32989.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/452_Schematized_68256.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/451_pilling_57626.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/450_shoelace_70356.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/449_Apolitical_3403.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/448_bump_10188.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/447_Propagandizing_60592.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/446_CLIQUES_14228.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/445_Ligaturing_44435.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/444_Sunblocks_76084.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/443_nucleon_52513.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/442_OMAYYAD_53328.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/441_cantaloupes_11241.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/440_WILDCATTER_86572.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/439_Splurging_73592.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/438_electrocardiography_24972.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/437_assumes_4462.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/436_Fatalistically_28228.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/435_Tunnies_81163.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/434_Ebbs_24476.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/433_lavage_43608.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/432_TRANSLUCENT_80278.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/431_flub_29755.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/430_Tinseled_79239.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/429_Bookshelf_8755.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/428_Computing_15595.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/427_HENCHMEN_35792.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/426_repudiators_64984.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/425_burdeen_10281.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/424_LIVIA_44891.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/423_PICTORIALS_57491.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/422_magnetosphere_46028.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/421_ICEBREAKERS_37742.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/420_ACETONIC_728.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/419_astringent_4519.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/418_PULLEYS_61177.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/417_Acrimoniously_839.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/416_Tinctured_79189.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/415_racists_62062.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/414_Lingered_44627.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/413_Pokemon_58530.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/412_sanction_67640.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/411_BEEPER_6640.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/410_UNWILLINGLY_83434.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/409_Upholds_83518.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/408_tenuousness_78214.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/407_SCALLION_68076.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/406_jammy_41206.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/405_WYCLIFFE_87509.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/404_imperative_38256.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/403_Optimum_53581.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/402_Upgraded_83506.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/401_ACIDS_767.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/400_piloted_57646.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/399_safflowers_67356.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/398_Casualties_11922.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/397_FACTORIALS_27857.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/396_mooted_49757.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/395_Trailers_80068.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/394_Shipmate_70259.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/393_DEPOSES_20760.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/392_reformatory_63870.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/391_spited_73497.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/390_INCENSED_38692.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/389_Unattainable_81748.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/388_MUSSETT_50574.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/387_INVOCATIONS_40681.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/386_Refurnishing_63951.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/385_Graphed_33469.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/384_Heavily_35534.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/383_HARBOUR_34938.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/382_Relapsed_64310.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/381_juicily_41914.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/380_pissoir_57832.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/379_decently_19694.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/378_Flossed_29692.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/377_solarium_72558.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/376_Snakebite_72115.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/375_mushiness_50515.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/374_arizonian_3944.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/373_Administrators_1103.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/372_keyboardist_42340.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/371_Starving_74329.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/370_fawn_28330.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/369_Waded_85170.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/368_Microdot_48209.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/367_Creeks_17981.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/366_annihilation_2965.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/365_CHOPIN_13423.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/364_Particulate_55717.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/363_Kurd_42963.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/362_Shoving_70493.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/361_puds_61120.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/360_vicarious_84528.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/359_YOUNGSTERS_87855.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/358_DOCILELY_22996.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/357_devaluing_21241.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/356_MAYS_47297.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/355_CAMELLIA_11007.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/354_Exhausted_27221.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/353_Contumelious_16684.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/352_KNOTTED_42784.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/351_POLITY_58618.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/350_fibrils_28725.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/349_BLIMPS_8024.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/348_tolerated_79505.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/347_PATENT_55877.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/346_Bole_8556.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/345_accelerate_536.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/344_OXYMORA_54882.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/343_CHILDHOODS_13186.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/342_Trollope_80807.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/341_FARROW_28158.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/340_Nomination_51864.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/339_bimbos_7516.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/338_INEXACTLY_39233.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/337_older_53268.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/336_semaphoring_69291.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/335_PIGSKIN_57570.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/334_Spillway_73421.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/333_Attic_4718.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/332_galatea_31537.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/331_gorging_33184.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/330_Ecuadoran_24565.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/329_od_53049.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/328_memes_47690.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/327_DISOWNS_22481.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/326_broker_9724.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/325_JOYCEAN_41813.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/324_CHUNKY_13600.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/323_Unharnessing_82583.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/322_excelled_27028.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/321_FIFERS_28812.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/320_SCREE_68627.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/319_SMARTENS_71937.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/318_unction_82024.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/317_FROZEN_31078.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/316_Buckingham_9954.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/315_CALLIGRAPHIST_10915.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/314_Showbiz_70495.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/313_exchangeable_27055.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/312_TRAVIS_80428.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/311_FISHWIFE_29169.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/310_stereoscopes_74597.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/309_thickos_78642.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/308_receipted_63069.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/307_loam_44938.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/306_Rejoiced_64280.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/305_Goldfish_33051.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/304_Endpoint_25706.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/303_Teenybopper_77908.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/302_outguess_54057.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/301_CHECKOUTS_12948.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/300_ipod_40746.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/299_sixth_71203.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/298_Razed_62669.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/297_tyros_81554.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/296_Mistrials_49124.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/295_DOLES_23138.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/294_Croissant_18206.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/293_alibis_1996.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/292_Creakiest_17905.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/291_malign_46281.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/290_embassy_25250.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/289_Credits_17968.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/288_besets_7128.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/287_ENVYING_26155.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/286_monocular_49573.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/285_Scuppering_68830.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/284_BRUNEI_9859.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/283_Paraphernalia_55475.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/282_vermiculite_84367.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/281_inkstand_39623.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/280_Asimov_4261.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/279_Mixable_49177.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/278_frizzling_30985.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/277_Shakiness_69863.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/276_Carping_11700.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/275_CONTESTING_16531.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/274_FALLIBLY_27987.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/273_EYE_27740.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/272_achaean_731.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/271_aligns_2023.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/270_BIZHUB_7754.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/269_luminous_45618.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/268_Dishevelment_22321.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/267_ASSENT_4373.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/266_INTERROGATORIES_40358.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/265_whatnot_86133.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/264_ringgit_66161.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/263_POLESTARS_58570.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/262_dethroned_21192.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/261_BIRO_7654.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/260_Rostropovich_66708.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/259_Basks_6173.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/258_WALLOWS_85348.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/257_MOUNTAINTOPS_50065.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/256_CORRUPTED_17204.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/255_FRANCISCAN_30636.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/254_Inverse_40609.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/253_Vicegerent_84534.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/252_Angling_2858.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/251_blacker_7792.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/250_Tilt_79113.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/249_hippo_36239.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/248_Unimaginative_82657.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/247_Essential_26587.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/246_PROSPECTORS_60745.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/245_COMPASSES_15379.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/244_subtopic_75765.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/243_DISROBED_22623.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/242_Orchestrated_53650.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/241_Altruist_2298.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/240_gingers_32510.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/239_INDISTINGUISHABLE_39075.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/238_Betokening_7230.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/237_360_91.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/236_Hyperbolas_37595.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/235_clinchers_14185.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/234_insisted_39832.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/233_wiggle_86535.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/232_Corkers_17028.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/231_LAVONNE_43632.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/230_BULGARIA_10079.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/229_HAYS_35281.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/228_Edward_24676.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/227_Mansards_46566.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/226_Prophet_60626.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/225_outfit_54029.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/224_lovably_45391.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/223_Effacing_24700.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/222_Cations_12068.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/221_WORSEN_87295.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/220_PIKE_57578.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/219_disquietude_22603.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/218_BYRD_10602.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/217_GIORGIO_32534.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/216_lessors_44146.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/215_POWERHOUSES_59288.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/214_Chickweed_13147.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/213_SIGNAGE_70845.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/212_Wilberforce_86562.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/211_Dushanbe_24207.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/210_FLOORBOARD_29646.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/209_OUTGUESSED_54058.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/208_birdcage_7629.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/207_osmium_53876.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/206_Annoywares_2997.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/205_Remunerated_64587.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/204_Capsuled_11390.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/203_unsnapped_83225.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/202_molding_49395.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/201_hollowest_36515.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/200_Palatial_55086.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/199_Understand_82235.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/198_Hurlers_37413.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/197_Squiggles_73989.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/196_windlasses_86706.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/195_SPIRITUALS_73486.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/194_afn_1466.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/193_Tenpins_78180.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/192_caboodle_10668.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/191_vying_85147.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/190_VETOING_84468.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/189_ascribes_4213.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/188_gamete_31651.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/187_pagan_54989.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/186_Regularities_64077.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/185_STOREROOM_74947.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/184_MUDGUARDS_50210.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/183_Balsamic_5687.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/182_Thickenings_78631.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/181_Invoices_40684.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/180_ANNEXED_2957.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/179_Initializes_39573.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/178_Pentacles_56472.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/177_believable_6825.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/176_Ringside_66175.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/175_Shaolin_69932.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/174_Flagging_29275.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/173_PRESIDENT_59876.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/172_Sketching_71266.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/171_Condensation_15781.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/170_zoned_88110.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/169_METABOLITES_47988.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/168_Ragamuffins_62177.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/167_wastrels_85599.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/166_galleys_31570.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/165_AGAPE_1526.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/164_Outfits_54030.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/163_harem_34998.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/162_encoding_25592.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/161_Orly_53776.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/160_Dino_21774.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/159_Huzzahing_37490.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/158_Provencals_60861.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/157_decouples_19856.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/156_annette_2953.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/155_Land_43253.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/154_Footmen_30071.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/153_Psychoanalyst_61008.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/152_ODDITIES_53057.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/151_thees_78497.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/150_MALADROITLY_46216.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/149_democratizing_20465.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/148_plagiarize_57972.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/147_larkspur_43427.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/146_Harks_35009.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/145_Quarterly_61736.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/144_Radicalized_62106.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/143_SALACIOUS_67438.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/142_Deceases_19663.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/141_outcrops_53992.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/140_SHUTTLING_70675.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/139_gyros_34414.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/138_maggie_45985.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/137_confidences_15913.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/136_Saved_67973.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/135_slogs_71771.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/134_romancers_66536.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/133_sinister_71102.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/132_Supergrass_76215.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/131_WALLED_85326.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/130_ROADWORTHY_66344.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/129_WORKROOM_87242.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/128_nicky_51592.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/127_Bulimics_10092.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/126_grinders_33759.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/125_Enchantresses_25565.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/124_Drooped_23865.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/123_TENTH_78206.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/122_UPTAKES_83612.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/121_anesthesia_2791.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/120_meteorology_48057.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/119_eschews_26517.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/118_GNOMES_32908.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/117_erlanger_26401.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/116_LIFELONG_44402.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/115_DREAR_23739.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/114_bodysuit_8475.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/113_Wimp_86650.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/112_SCAVENGER_68216.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/111_SNOOKERED_72266.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/110_liveried_44873.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/109_crumbles_18398.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/108_RAVAGED_62618.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/107_POTHERBS_59191.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/106_CRUSADE_18427.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/105_mainstreamed_46150.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/104_abducting_233.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/103_impolitely_38381.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/102_amparo_2558.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/101_Orientalists_53733.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/100_Cosmetician_17265.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/99_FISSION_29174.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/98_smoke_72020.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/97_PRENTICE_59720.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/96_PITCHMEN_57863.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/95_mien_48334.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/94_redder_63479.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/93_Byers_10584.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/92_forefathers_30176.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/91_ENDOWS_25705.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/90_Restrain_65350.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/89_aegis_1327.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/88_ANATHEMATIZED_2694.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/87_BONDSMEN_8643.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/86_strategically_75089.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/85_DYERS_24287.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/84_REMIT_64527.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/83_Tornadoes_79737.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/82_Stickleback_74666.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/81_Innate_39641.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/80_KAHUNAS_42075.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/79_Lowlife_45442.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/78_maseru_46968.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/77_smallholders_71922.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/76_POSTPONES_59137.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/75_Awaits_5131.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/74_burgher_10311.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/73_Griefs_33712.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/72_repression_64898.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/71_longhouses_45184.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/70_SYRINGE_77064.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/69_Sociological_72466.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/68_Circumnavigations_13755.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/67_Letdowns_44153.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/66_AGERATUM_1548.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/65_Evidently_26915.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/64_SWAYED_76704.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/63_riotous_66190.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/62_analgesia_2642.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/61_Separators_69503.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/60_Inconclusive_38813.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/59_hyperglycemia_37600.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/58_Brownish_9818.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/57_Yob_87805.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/56_EDGEWISE_24599.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/55_chameleon_12594.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/54_Opalescence_53447.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/53_orates_53620.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/52_CONFABBING_15856.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/51_TRAINER_80077.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/50_DEPLOY_20726.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/49_Johanna_41658.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/48_workroom_87242.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/47_Imaginable_38007.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/46_GRAINIEST_33358.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/45_OHSA_53208.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/44_efflorescence_24741.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/43_Dad_19006.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/42_Instantly_39907.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/41_PRESBYTERY_59814.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/40_mayors_47293.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/39_HUMOROUS_37330.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/38_schoolgirl_68350.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/37_PERCEIVABLE_56554.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/36_STEEPENING_74500.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/35_dispatches_22499.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/34_WIDENS_86495.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/33_PINCHES_57679.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/32_RTD_66900.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/31_plagiarist_57970.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/30_APPARENT_3464.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/29_TWOS_81463.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/28_trailblazers_80064.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/27_UNHURRIED_82623.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/26_Flagellates_29270.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/25_Traced_79978.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/24_Indissolubility_39069.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/23_effervesced_24722.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/22_Hackle_34465.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/21_imperf_38263.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/20_ARMORING_4001.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/19_Etas_26645.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/18_Caracas_11433.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/17_REPRICE_64903.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/16_Grilled_33732.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/15_DOCTORED_23020.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/14_Sandier_67677.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/13_DEJECTEDLY_20218.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/12_Firehouse_29074.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/11_Nix_51772.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/10_Cynicism_18938.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/9_Womenfolk_87050.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/8_Disassociation_21976.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/7_bally_5673.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/6_Dubbed_23983.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/5_Liturgies_44851.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/4_Yelped_87747.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/3_Dicta_21492.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/2_molds_49399.jpg
# mnt/ramdisk/max/90kDICT32px/2717/1/1_flippancy_29585.jpg
# mnt/ramdisk/max/90kDICT32px/2716/
# mnt/ramdisk/max/90kDICT32px/2716/7/
# mnt/ramdisk/max/90kDICT32px/2716/7/194_PORE_58916.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/193_MISTAKEN_49094.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/192_CALIFORNIAN_10880.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/191_Detect_21140.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/190_turkestan_81215.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/189_Baroque_6038.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/188_CUSHION_18796.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/187_Norm_52248.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/186_tarmacs_77565.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/185_De_19424.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/184_CHEESY_13010.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/183_Preassigned_59424.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/182_bearers_6428.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/181_INUNDATIONS_40549.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/180_Suntan_76157.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/179_venezuelan_84252.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/178_TOOTHPICK_79645.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/177_QUINCY_61898.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/176_Swisses_76854.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/175_Antiparticle_3212.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/174_impedimenta_38236.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/173_CLINGIER_14193.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/172_strindberg_75226.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/171_Spaciest_73031.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/170_nastiest_50946.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/169_SCURFIEST_68834.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/168_unloosen_82838.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/167_Slaver_71544.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/166_pleb_58214.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/165_ADEPTLY_1005.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/164_boatswains_8407.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/163_gorp_33203.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/162_svelter_76596.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/161_rotors_66739.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/160_tearooms_77830.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/159_doubting_23431.jpg
# mnt/ramdisk/max/90kDICT32px/2716/7/158_TYRANNOUS_81544.jpg
# ...
# mnt/ramdisk/max/90kDICT32px/2715/5/461_HUMUS_37347.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/460_publications_61077.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/459_Circumpolar_13756.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/458_NONVIRULENT_52209.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/457_Parable_55384.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/456_Cruet_18374.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/455_crookedness_18223.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/454_h_34422.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/453_JAIME_41172.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/452_Plebiscite_58220.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/451_Convalesced_16697.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/450_Sounds_72908.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/449_hardhat_34957.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/448_Buckets_9950.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/447_gawping_31958.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/446_Medievalists_47522.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/445_souses_72944.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/444_Lateraling_43495.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/443_whelked_86182.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/442_widened_86490.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/441_RYLEY_67217.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/440_Illustrated_37989.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/439_Pacifism_54927.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/438_arbitragers_3745.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/437_tonga_79580.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/436_Corer_17004.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/435_braked_9206.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/434_DISOBLIGE_22454.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/433_quasar_61748.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/432_TALKY_77326.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/431_copped_16915.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/430_SNACKING_72098.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/429_seined_69204.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/428_SHIES_70175.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/427_Chemicals_13024.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/426_PHARMACOPOEIA_57137.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/425_MILDEWING_48382.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/424_Smog_72015.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/423_Ravines_62640.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/422_CONCEIVING_15637.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/421_WORKING_87224.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/420_SANTIAGO_67747.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/419_Beardless_6423.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/418_Embolden_25290.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/417_Ousted_53943.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/416_semantics_69287.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/415_BILATERALLY_7458.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/414_FLOPHOUSES_29657.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/413_Stepchildren_74563.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/412_Kiowa_42578.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/411_giorgio_32534.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/410_abstemious_458.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/409_Staking_74143.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/408_fruitlessness_31103.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/407_RUSS_67145.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/406_cooperates_16861.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/405_fulsomeness_31213.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/404_shook_70374.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/403_chrystal_13553.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/402_stick_74657.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/401_DOLE_23133.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/400_SA_67220.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/399_simulating_71030.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/398_latte_43533.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/397_Whop_86444.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/396_footings_30062.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/395_SCABROUS_68047.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/394_Pippins_57789.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/393_carr_11709.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/392_swizzles_76878.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/391_effervesce_24721.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/390_appears_3478.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/389_Duplex_24172.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/388_unfeminine_82459.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/387_overloading_54554.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/386_INGRAINED_39485.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/385_fatherless_28249.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/384_punster_61295.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/383_LIGHTNESS_44457.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/382_phial_57173.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/381_Mulligans_50305.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/380_louvered_45386.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/379_Kindest_42517.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/378_besetting_7129.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/377_IMPERVIOUSLY_38313.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/376_SPREADERS_73753.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/375_limp_44566.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/374_KLAXONS_42656.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/373_erich_26387.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/372_JEPHTHAH_41412.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/371_SPOOLS_73653.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/370_airfares_1743.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/369_pencilings_56383.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/368_DECLAMATIONS_19757.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/367_lethal_44155.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/366_loathers_44956.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/365_bombard_8601.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/364_Disbelieves_22002.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/363_Employs_25464.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/362_Equestrians_26289.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/361_SCORPIO_68495.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/360_CAFETERIA_10743.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/359_PATCHY_55871.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/358_Millwrights_48497.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/357_VERSION_84405.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/356_delayers_20236.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/355_Jutting_42045.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/354_scarfing_68169.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/353_SEDENTARY_69089.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/352_FILAMENTS_28854.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/351_Authoritative_4938.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/350_Consequent_16234.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/349_Effed_24714.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/348_adulterous_1228.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/347_bullish_10145.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/346_BROWNS_9822.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/345_restorations_65340.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/344_FIDGETED_28771.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/343_Pfennigs_57089.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/342_YELPS_87749.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/341_Yielding_87789.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/340_officially_53142.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/339_BEFITTING_6671.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/338_GIRO_32561.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/337_gratification_33511.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/336_TOGETHER_79457.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/335_consulting_16424.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/334_instates_39911.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/333_Cockerels_14594.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/332_COUPERIN_17525.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/331_Strikebreaker_75215.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/330_streptococcus_75164.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/329_Nonnegotiable_52066.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/328_Scratchiest_68602.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/327_interring_40347.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/326_reflexive_63843.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/325_Chesterfields_13076.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/324_countdowns_17405.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/323_Motorboats_50007.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/322_Ridden_66029.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/321_mri_50158.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/320_estranges_26635.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/319_HAMAN_34685.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/318_Totes_79827.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/317_Leviers_44218.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/316_Unschooled_83148.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/315_EXPEDITION_27376.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/314_Brit_9635.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/313_peregrination_56602.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/312_Meatloaves_47445.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/311_up_83473.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/310_perverting_56959.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/309_misidentified_48935.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/308_FARMLAND_28142.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/307_postcode_59079.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/306_sonatinas_72724.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/305_PARRED_55641.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/304_Frequenters_30834.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/303_WIGGLY_86544.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/302_TECHNO_77866.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/301_Towhee_79927.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/300_NIPPLE_51735.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/299_EXPATS_27346.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/298_Halves_34680.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/297_originators_53760.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/296_MATINEES_47135.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/295_mohorovicic_49346.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/294_twinkling_81411.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/293_negates_51200.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/292_unappetizing_81728.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/291_cut_18835.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/290_MENHADEN_47758.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/289_Profiteering_60387.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/288_Cattails_12086.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/287_subaltern_75502.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/286_PORTO_58999.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/285_speculate_73252.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/284_Toboggans_79415.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/283_oxygenating_54880.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/282_slocum_71762.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/281_DISENTANGLEMENT_22250.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/280_Cessna_12499.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/279_hoots_36789.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/278_rectilinear_63421.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/277_Ink_39612.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/276_SNUGGING_72392.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/275_DOCKETS_23005.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/274_ALNITAK_2195.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/273_Ninepins_51707.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/272_dawdlers_19373.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/271_NOTEPAD_52377.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/270_Interpretations_40327.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/269_PARESES_55558.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/268_poltava_58663.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/267_Grubbing_33976.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/266_types_81492.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/265_coatings_14519.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/264_crimping_18098.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/263_LAYOFF_43687.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/262_wellsprings_86015.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/261_Stutterers_75457.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/260_commentates_15203.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/259_lampreys_43233.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/258_gruesome_33991.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/257_applebee_3522.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/256_FROWNING_31070.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/255_KIPPED_42583.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/254_IMPENITENT_38253.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/253_sunni_76130.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/252_moppets_49774.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/251_FEWEST_28689.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/250_wavers_85716.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/249_meatball_47438.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/248_ALMACH_2179.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/247_CATKINS_12070.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/246_BEDAZZLEMENT_6537.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/245_equivalent_26320.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/244_Humerus_37290.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/243_lieder_44371.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/242_keened_42228.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/241_lampshades_43236.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/240_Handlebars_34798.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/239_LIPSTICKING_44712.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/238_hair_34525.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/237_chants_12690.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/236_STALLONE_74176.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/235_Survive_76524.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/234_DOORJAMBS_23293.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/233_SEXTUPLETS_69778.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/232_coiners_14809.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/231_SECLUDE_68999.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/230_SPENCE_73321.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/229_reorient_64709.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/228_AIRFARE_1742.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/227_anointed_3024.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/226_murmured_50469.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/225_Penitentiary_56424.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/224_deutschland_21235.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/223_meriting_47884.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/222_correlated_17158.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/221_percentiles_56563.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/220_SISSIER_71155.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/219_inspectorate_39866.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/218_EPIGRAMMATIC_26206.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/217_Busts_10489.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/216_EQUIPPING_26308.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/215_beat_6446.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/214_preeminent_59583.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/213_poled_58561.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/212_scarify_68176.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/211_Premeds_59690.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/210_Korzybski_42875.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/209_beautify_6491.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/208_JESSICA_41450.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/207_EWER_26954.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/206_ADDS_988.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/205_Pores_58918.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/204_constables_16339.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/203_corkage_17025.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/202_flysheet_29869.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/201_PAPOU_55374.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/200_Shrimped_70578.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/199_chunder_13590.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/198_mondays_49490.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/197_negev_51212.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/196_EMBLEM_25281.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/195_Bhaji_7306.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/194_MADRASES_45958.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/193_Superannuating_76173.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/192_GUESSTIMATE_34106.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/191_FRIGHTENINGLY_30923.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/190_Lame_43191.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/189_Intimates_40431.jpg
# mnt/ramdisk/max/90kDICT32px/2715/5/188_Instrumentally_39966.jpg
# Buffered data was truncated after reaching the output size limit.

# %%
char_list = string.ascii_letters+string.digits
 
def encode_to_labels(txt):
    # encoding each output word into digits
    dig_lst = []
    for index, char in enumerate(txt):
        try:
            dig_lst.append(char_list.index(char))
        except:
            print(char)
        
    return dig_lst

# %%
path = '/content/mnt/ramdisk/max/90kDICT32px'
 
 
# lists for training dataset
training_img = []
training_txt = []
train_input_length = []
train_label_length = []
orig_txt = []
 
#lists for validation dataset
valid_img = []
valid_txt = []
valid_input_length = []
valid_label_length = []
valid_orig_txt = []
 
max_label_len = 0
 
i =1 
flag = 0
 
for root, dirnames, filenames in os.walk(path):
 
    for f_name in fnmatch.filter(filenames, '*.jpg'):
        # read input image and convert into gray scale image
        img = cv2.cvtColor(cv2.imread(os.path.join(root, f_name)), cv2.COLOR_BGR2GRAY)   
 
        # convert each image of shape (32, 128, 1)
        w, h = img.shape
        if h > 128 or w > 32:
            continue
        if w < 32:
            add_zeros = np.ones((32-w, h))*255
            img = np.concatenate((img, add_zeros))
 
        if h < 128:
            add_zeros = np.ones((32, 128-h))*255
            img = np.concatenate((img, add_zeros), axis=1)
        img = np.expand_dims(img , axis = 2)
        
        # Normalize each image
        img = img/255.
        
        # get the text from the image
        txt = f_name.split('_')[1]
        
        # compute maximum length of the text
        if len(txt) > max_label_len:
            max_label_len = len(txt)
            
           
        # split the 150000 data into validation and training dataset as 10% and 90% respectively
        if i%10 == 0:     
            valid_orig_txt.append(txt)   
            valid_label_length.append(len(txt))
            valid_input_length.append(31)
            valid_img.append(img)
            valid_txt.append(encode_to_labels(txt))
        else:
            orig_txt.append(txt)   
            train_label_length.append(len(txt))
            train_input_length.append(31)
            training_img.append(img)
            training_txt.append(encode_to_labels(txt)) 
        
        # break the loop if total data is 150000
        if i == 50000:
            flag = 1
            break
        i+=1
    if flag == 1:
        break

# %%
train_padded_txt = pad_sequences(training_txt, maxlen=max_label_len, padding='post', value = len(char_list))
valid_padded_txt = pad_sequences(valid_txt, maxlen=max_label_len, padding='post', value = len(char_list))

# %%
# input with shape of height=32 and width=128 
inputs = Input(shape=(32,128,1))
 
conv_1 = Conv2D(64, (3,3), activation = 'relu', padding='same')(inputs)
pool_1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_1)
 
conv_2 = Conv2D(128, (3,3), activation = 'relu', padding='same')(pool_1)
pool_2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_2)
 
conv_3 = Conv2D(256, (3,3), activation = 'relu', padding='same')(pool_2)
 
conv_4 = Conv2D(256, (3,3), activation = 'relu', padding='same')(conv_3)
pool_4 = MaxPool2D(pool_size=(2, 1))(conv_4)
 
conv_5 = Conv2D(512, (3,3), activation = 'relu', padding='same')(pool_4)
batch_norm_5 = BatchNormalization()(conv_5)
 
conv_6 = Conv2D(512, (3,3), activation = 'relu', padding='same')(batch_norm_5)
batch_norm_6 = BatchNormalization()(conv_6)
pool_6 = MaxPool2D(pool_size=(2, 1))(batch_norm_6)
 
conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool_6)
 
squeezed = Lambda(lambda x: K.squeeze(x, 1))(conv_7)
 
blstm_1 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.2))(squeezed)
blstm_2 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.2))(blstm_1)
 
outputs = Dense(len(char_list)+1, activation = 'softmax')(blstm_2)

act_model = Model(inputs, outputs)

# %%
act_model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 128, 1)]      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 32, 128, 64)       640
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 64, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 64, 128)       73856
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 32, 128)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 8, 32, 256)        295168
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 8, 32, 256)        590080
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 32, 256)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 4, 32, 512)        1180160
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 32, 512)        2048
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 4, 32, 512)        2359808
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 32, 512)        2048
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 2, 32, 512)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 1, 31, 512)        1049088
# _________________________________________________________________
# lambda_3 (Lambda)            (None, 31, 512)           0
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 31, 256)           656384
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 31, 256)           394240
# _________________________________________________________________
# dense_3 (Dense)              (None, 31, 63)            16191
# =================================================================
# Total params: 6,619,711
# Trainable params: 6,617,663
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')
 
 
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
 
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)
 
 
loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, labels, input_length, label_length])

#model to be used at training time
model = Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer = 'adam')
 
filepath="best_model.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint]

# %%
training_img = np.array(training_img)
train_input_length = np.array(train_input_length)
train_label_length = np.array(train_label_length)

valid_img = np.array(valid_img)
valid_input_length = np.array(valid_input_length)
valid_label_length = np.array(valid_label_length)

# %%
batch_size = 256
epochs = 10


model.fit(x=[training_img, train_padded_txt, train_input_length, train_label_length], 
          y=np.zeros(len(training_img)), batch_size=batch_size, epochs = epochs,
          validation_data = ([valid_img, valid_padded_txt, valid_input_length, valid_label_length], 
                             [np.zeros(len(valid_img))]), verbose = 1, callbacks = callbacks_list)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fe148e75f28> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/tmp/tmpds01l15c.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fe148e75f28> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/tmp/tmpds01l15c.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7fe14b317048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/tmp/tmp36syser3.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7fe14b317048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/tmp/tmp36syser3.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 176/176 [==============================] - ETA: 0s - loss: 32.6023 WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fe14a279b70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/tmp/tmpy5ssxong.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fe14a279b70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/tmp/tmpy5ssxong.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 176/176 [==============================] - 4363s 25s/step - loss: 32.5800 - val_loss: 27.3578
#
# Epoch 00001: val_loss improved from inf to 27.35784, saving model to best_model.hdf5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-65-5ba82ab7c184> in <module>()
#       6           y=np.zeros(len(training_img)), batch_size=batch_size, epochs = epochs,
#       7           validation_data = ([valid_img, valid_padded_txt, valid_input_length, valid_label_length],
# ----> 8                              [np.zeros(len(valid_img))]), verbose = 1, callbacks = callbacks_list)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1143           epoch_logs.update(val_logs)
#    1144
# -> 1145         callbacks.on_epoch_end(epoch, epoch_logs)
#    1146         training_logs = epoch_logs
#    1147         if self.stop_training:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     426     for callback in self.callbacks:
#     427       if getattr(callback, '_supports_tf_logs', False):
# --> 428         callback.on_epoch_end(epoch, logs)
#     429       else:
#     430         if numpy_logs is None:  # Only convert once.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#    1342     # pylint: disable=protected-access
#    1343     if self.save_freq == 'epoch':
# -> 1344       self._save_model(epoch=epoch, logs=logs)
#    1345
#    1346   def _should_save_on_batch(self, batch):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _save_model(self, epoch, logs)
#    1416                         'directory: {}'.format(filepath))
#    1417         # Re-throw the error for any other causes.
# -> 1418         raise e
#    1419
#    1420   def _get_file_path(self, epoch, logs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _save_model(self, epoch, logs)
#    1394                     filepath, overwrite=True, options=self._options)
#    1395               else:
# -> 1396                 self.model.save(filepath, overwrite=True, options=self._options)
#    1397             else:
#    1398               if self.verbose > 0:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2000     # pylint: enable=line-too-long
#    2001     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 2002                     signatures, options, save_traces)
#    2003
#    2004   def save_weights(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     152           'or using `save_weights`.')
#     153     hdf5_format.save_model_to_hdf5(
# --> 154         model, filepath, overwrite, include_optimizer)
#     155   else:
#     156     saved_model_save.save(model, filepath, overwrite, include_optimizer,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     106       gfile.MakeDirs(dirpath)
#     107
# --> 108     f = h5py.File(filepath, mode='w')
#     109     opened_new_file = True
#     110   else:
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     177         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     178     elif mode == 'w':
# --> 179         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     180     elif mode == 'a':
#     181         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = 'best_model.hdf5', errno = 28, error message = 'No space left on device', flags = 13, o_flags = 242)

# %%
# load the saved best model weights
act_model.load_weights('best_model.hdf5')
 
# predict outputs on validation images
prediction = act_model.predict(valid_img[:10])
 
# use CTC decoder
out = K.get_value(K.ctc_decode(prediction, input_length=np.ones(prediction.shape[0])*prediction.shape[1],
                         greedy=True)[0][0])
 
# see the results
i = 0
for x in out:
    print("original_text =  ", valid_orig_txt[i])
    print("predicted text = ", end = '')
    for p in x:  
        if int(p) != -1:
            print(char_list[int(p)], end = '')       
    print('\n')
    i+=1
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-66-28a7f979e1c5> in <module>()
#       1
#       2 # load the saved best model weights
# ----> 3 act_model.load_weights('best_model.hdf5')
#       4
#       5 # predict outputs on validation images
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2225           'first, then load the weights.')
#    2226     self._assert_weights_created()
# -> 2227     with h5py.File(filepath, 'r') as f:
#    2228       if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2229         f = f['model_weights']
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'best_model.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
